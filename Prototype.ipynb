# %% [markdown]
# # Project Proposal
#
# ## Prototyping
#
# import mysql.connector
# import pandas as pd

# %%
cnx = mysql.connector.connect(user='root', password='root',
                              host='127.0.0.1',
                              database='trouble_shoot')

# %%
c = cnx.cursor()

# %%
# Gather sum of anxiety score and depression score from all participants

c. execute('''SELECT Q2A + Q4A + Q7A + Q9A + Q15A + Q19A + Q20A + Q23A + Q25A + Q28A + Q30A + Q36A + Q40A + Q41A AS Anxiety, 
            Q3A + Q5A + Q10A + Q13A + Q16A + Q17A + Q21A + Q24A + Q26A + Q31A + Q34A + Q37A + Q38A + Q42A AS Depression FROM DASS_Anxiety
            INNER JOIN DASS_Depression
            ON DASS_Anxiety.Test_ID = DASS_Depression.Test_ID''')

df = pd.DataFrame(c.fetchall())

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# %%
# Visualize distribution of anxiety score and depression score

fig =plt.figure(figsize=(15,12))

gs = GridSpec(4, 4)

ax_scatter = fig.add_subplot(gs[1:4, 0:3])
ax_hist_y = fig.add_subplot(gs[0,0:3])
ax_hist_x = fig.add_subplot(gs[1:4, 3])

ax_scatter.scatter(df[0], df[1], alpha=0.2, color='black')
ax_hist_x.hist(df[0], bins=20, orientation = 'horizontal', alpha=0.5, color='black')
ax_hist_y.hist(df[1], bins=20, orientation = 'vertical', alpha=0.5, color='black')


#plt.xlabel("X axis label")
plt.show()

# %%
cnx.close()

cnx = mysql.connector.connect(user='root', password='root',
                              host='127.0.0.1',
                              database='trouble_shoot')

c = cnx.cursor()

# %%
# Gather sum of anxiety score and depression score from male participants


c. execute('''SELECT Q2A + Q4A + Q7A + Q9A + Q15A + Q19A + Q20A + Q23A + Q25A + Q28A + Q30A + Q36A + Q40A + Q41A AS Anxiety, 
            Q3A + Q5A + Q10A + Q13A + Q16A + Q17A + Q21A + Q24A + Q26A + Q31A + Q34A + Q37A + Q38A + Q42A AS Depression FROM DASS_Anxiety
            INNER JOIN DASS_Depression
            ON DASS_Anxiety.Test_ID = DASS_Depression.Test_ID
            INNER JOIN DASS_Test
            ON DASS_Anxiety.Test_ID = DASS_Test.Test_ID            
            INNER JOIN Test_Taker
            ON DASS_Test.Taker_ID = Test_Taker.Taker_ID  
            WHERE Test_Taker.gender = 1''')

# %%
df = pd.DataFrame(c.fetchall())

# %%
# Visualize distribution of anxiety score and depression score of male

fig =plt.figure(figsize=(15,12))
#ax = plt.subplot()
gs = GridSpec(4, 4)

ax_scatter = fig.add_subplot(gs[1:4, 0:3])
ax_hist_y = fig.add_subplot(gs[0,0:3])
ax_hist_x = fig.add_subplot(gs[1:4, 3])

ax_scatter.scatter(df[0], df[1], alpha=0.2)
ax_hist_x.hist(df[0], bins=20, orientation = 'horizontal', alpha=0.5)
ax_hist_y.hist(df[1], bins=20, orientation = 'vertical', alpha=0.5)

#ax.set_xlabel("Anxiety Score (sum)")
#ax.set_ylabel("Stress Score (sum)")

plt.show()

# %%
# Gather sum of anxiety score and depression score from female participants

c. execute('''SELECT Q2A + Q4A + Q7A + Q9A + Q15A + Q19A + Q20A + Q23A + Q25A + Q28A + Q30A + Q36A + Q40A + Q41A AS Anxiety, 
            Q3A + Q5A + Q10A + Q13A + Q16A + Q17A + Q21A + Q24A + Q26A + Q31A + Q34A + Q37A + Q38A + Q42A AS Depression FROM DASS_Anxiety
            INNER JOIN DASS_Depression
            ON DASS_Anxiety.Test_ID = DASS_Depression.Test_ID
            INNER JOIN DASS_Test
            ON DASS_Anxiety.Test_ID = DASS_Test.Test_ID            
            INNER JOIN Test_Taker
            ON DASS_Test.Taker_ID = Test_Taker.Taker_ID  
            WHERE Test_Taker.gender = 2''')

# %%
df = pd.DataFrame(c.fetchall())
df.head()
# Out:
#     0   1
# 0  48  41
# 1  31  38
# 2  26  53
# 3  31  30
# 4  20  27

# %%
# Visualize distribution of anxiety score and depression score of female

fig =plt.figure(figsize=(15,12))
#ax = plt.subplot()
gs = GridSpec(4, 4)

ax_scatter = fig.add_subplot(gs[1:4, 0:3])
ax_hist_y = fig.add_subplot(gs[0,0:3])
ax_hist_x = fig.add_subplot(gs[1:4, 3])

ax_scatter.scatter(df[0], df[1], alpha=0.2, color='red')
ax_hist_x.hist(df[0], bins=20, orientation = 'horizontal', alpha=0.5, color='red')
ax_hist_y.hist(df[1], bins=20, orientation = 'vertical', alpha=0.5, color='red')

plt.show()
